# %%
pip install ollama==0.4.7
# Out:
# Collecting ollama==0.4.7
#   Using cached ollama-0.4.7-py3-none-any.whl.metadata (4.7 kB)
# Collecting httpx<0.29,>=0.27 (from ollama==0.4.7)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic<3.0.0,>=2.9.0 (from ollama==0.4.7)
#   Using cached pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Collecting anyio (from httpx<0.29,>=0.27->ollama==0.4.7)
#   Downloading anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting certifi (from httpx<0.29,>=0.27->ollama==0.4.7)
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting httpcore==1.* (from httpx<0.29,>=0.27->ollama==0.4.7)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<0.29,>=0.27->ollama==0.4.7)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<0.29,>=0.27->ollama==0.4.7)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.9.0->ollama==0.4.7)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3.0.0,>=2.9.0->ollama==0.4.7)
#   Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama==0.4.7) (4.15.0)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.9.0->ollama==0.4.7)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from anyio->httpx<0.29,>=0.27->ollama==0.4.7) (1.3.0)
# Collecting sniffio>=1.1 (from anyio->httpx<0.29,>=0.27->ollama==0.4.7)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached ollama-0.4.7-py3-none-any.whl (13 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pydantic-2.11.9-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/2.0 MB 1.5 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/2.0 MB 1.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.7 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.4 MB/s  0:00:01
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
# Installing collected packages: typing-inspection, sniffio, pydantic-core, idna, h11, certifi, annotated-types, pydantic, httpcore, anyio, httpx, ollama
#
#    ------ ---------------------------------  2/12 [pydantic-core]
#    ---------- -----------------------------  3/12 [idna]
#    ---------- -----------------------------  3/12 [idna]
#    ------------- --------------------------  4/12 [h11]
#    ------------- --------------------------  4/12 [h11]
#    -------------------- -------------------  6/12 [annotated-types]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    -------------------------- -------------  8/12 [httpcore]
#    -------------------------- -------------  8/12 [httpcore]
#    -------------------------- -------------  8/12 [httpcore]
#    -------------------------- -------------  8/12 [httpcore]
#    -------------------------- -------------  8/12 [httpcore]
#    -------------------------- -------------  8/12 [httpcore]
#    ------------------------------ ---------  9/12 [anyio]
#    ------------------------------ ---------  9/12 [anyio]
#    ------------------------------ ---------  9/12 [anyio]
#    ------------------------------ ---------  9/12 [anyio]
#    ------------------------------ ---------  9/12 [anyio]
#    ------------------------------ ---------  9/12 [anyio]
#    --------------------------------- ------ 10/12 [httpx]
#    --------------------------------- ------ 10/12 [httpx]
#    --------------------------------- ------ 10/12 [httpx]
#    --------------------------------- ------ 10/12 [httpx]
#    --------------------------------- ------ 10/12 [httpx]
#    --------------------------------- ------ 10/12 [httpx]
#    ------------------------------------ --- 11/12 [ollama]
#    ---------------------------------------- 12/12 [ollama]
#
# Successfully installed annotated-types-0.7.0 anyio-4.11.0 certifi-2025.8.3 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 ollama-0.4.7 pydantic-2.11.9 pydantic-core-2.33.2 sniffio-1.3.1 typing-inspection-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install ollama==0.4.7
import ollama
llm = "qwen2.5"

# %%
stream = ollama.generate(model=llm, prompt='''what time is it?''', stream=True)
for chunk in stream:
    print(chunk['response'], end='', flush=True)
# Out:
# To provide you with the current time, I would need to check my system's clock. However, as an AI, I don't have direct access to real-time data like the current local time without your assistance. If you're using this chat interface, you can usually check the time on your device or ask me for the time in a specific location if you provide that information. Would you like me to help with that?

# %% [markdown]
# 1.1. Simple (WebSearch)

# %%
pip install langchain-community==0.3.17
# Out:
# Collecting langchain-community==0.3.17Note: you may need to restart the kernel to use updated packages.
#
#   Using cached langchain_community-0.3.17-py3-none-any.whl.metadata (2.4 kB)
# Collecting langchain-core<1.0.0,>=0.3.34 (from langchain-community==0.3.17)
#   Using cached langchain_core-0.3.76-py3-none-any.whl.metadata (3.7 kB)
# Collecting langchain<1.0.0,>=0.3.18 (from langchain-community==0.3.17)
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain-community==0.3.17)
#   Downloading sqlalchemy-2.0.43-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Collecting requests<3,>=2 (from langchain-community==0.3.17)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting PyYAML>=5.3 (from langchain-community==0.3.17)
#   Using cached PyYAML-6.0.2-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community==0.3.17)
#   Downloading aiohttp-3.12.15-cp310-cp310-win_amd64.whl.metadata (7.9 kB)
# Collecting tenacity!=8.4.0,<10,>=8.1.0 (from langchain-community==0.3.17)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community==0.3.17)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community==0.3.17)
#   Using cached pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith<0.4,>=0.1.125 (from langchain-community==0.3.17)
#   Using cached langsmith-0.3.45-py3-none-any.whl.metadata (15 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community==0.3.17)
#   Using cached httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting numpy<2,>=1.26.4 (from langchain-community==0.3.17)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.17)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.17)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.17)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.17)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.17)
#   Downloading frozenlist-1.7.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.17)
#   Downloading multidict-6.6.4-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.17)
#   Downloading propcache-0.3.2-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.17)
#   Downloading yarl-1.20.1-cp310-cp310-win_amd64.whl.metadata (76 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.17)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.17)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain<1.0.0,>=0.3.18->langchain-community==0.3.17)
#   Using cached langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from langchain<1.0.0,>=0.3.18->langchain-community==0.3.17) (2.11.9)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.17)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.34->langchain-community==0.3.17)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-community==0.3.17) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-community==0.3.17) (25.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain-community==0.3.17)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community==0.3.17) (0.28.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.125->langchain-community==0.3.17)
#   Downloading orjson-3.11.3-cp310-cp310-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.4,>=0.1.125->langchain-community==0.3.17)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.1.125->langchain-community==0.3.17)
#   Downloading zstandard-0.23.0-cp310-cp310-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: anyio in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.17) (4.11.0)
# Requirement already satisfied: certifi in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.17) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.17) (1.0.9)
# Requirement already satisfied: idna in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.17) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.17) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.18->langchain-community==0.3.17) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.18->langchain-community==0.3.17) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.18->langchain-community==0.3.17) (0.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.17)
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2->langchain-community==0.3.17)
#   Downloading charset_normalizer-3.4.3-cp310-cp310-win_amd64.whl.metadata (37 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain-community==0.3.17)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain-community==0.3.17)
#   Downloading greenlet-3.2.4-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.17)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.17) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.17) (1.3.1)
# Using cached langchain_community-0.3.17-py3-none-any.whl (2.5 MB)
# Downloading aiohttp-3.12.15-cp310-cp310-win_amd64.whl (452 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached langchain_core-0.3.76-py3-none-any.whl (447 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Using cached langsmith-0.3.45-py3-none-any.whl (363 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.6.4-cp310-cp310-win_amd64.whl (46 kB)
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.8/15.8 MB 1.7 MB/s eta 0:00:09
#    -- ------------------------------------- 1.0/15.8 MB 1.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.3/15.8 MB 1.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.8/15.8 MB 1.7 MB/s eta 0:00:09
#    ----- ---------------------------------- 2.1/15.8 MB 1.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.4/15.8 MB 1.6 MB/s eta 0:00:09
#    ------ --------------------------------- 2.6/15.8 MB 1.5 MB/s eta 0:00:09
#    ------- -------------------------------- 3.1/15.8 MB 1.6 MB/s eta 0:00:09
#    -------- ------------------------------- 3.4/15.8 MB 1.7 MB/s eta 0:00:08
#    --------- ------------------------------ 3.9/15.8 MB 1.6 MB/s eta 0:00:08
#    ---------- ----------------------------- 4.2/15.8 MB 1.7 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.5/15.8 MB 1.7 MB/s eta 0:00:07
#    ------------ --------------------------- 5.0/15.8 MB 1.7 MB/s eta 0:00:07
#    ------------- -------------------------- 5.2/15.8 MB 1.7 MB/s eta 0:00:07
#    -------------- ------------------------- 5.8/15.8 MB 1.7 MB/s eta 0:00:07
#    --------------- ------------------------ 6.0/15.8 MB 1.7 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.6/15.8 MB 1.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 6.8/15.8 MB 1.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 7.1/15.8 MB 1.7 MB/s eta 0:00:06
#    ------------------- -------------------- 7.6/15.8 MB 1.7 MB/s eta 0:00:05
#    ------------------- -------------------- 7.6/15.8 MB 1.7 MB/s eta 0:00:05
#    -------------------- ------------------- 8.1/15.8 MB 1.7 MB/s eta 0:00:05
#    --------------------- ------------------ 8.4/15.8 MB 1.7 MB/s eta 0:00:05
#    --------------------- ------------------ 8.7/15.8 MB 1.7 MB/s eta 0:00:05
#    ---------------------- ----------------- 8.9/15.8 MB 1.6 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.2/15.8 MB 1.6 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.2/15.8 MB 1.6 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.4/15.8 MB 1.5 MB/s eta 0:00:05
#    ------------------------ --------------- 9.7/15.8 MB 1.5 MB/s eta 0:00:05
#    ------------------------- -------------- 10.0/15.8 MB 1.5 MB/s eta 0:00:04
#    -------------------------- ------------- 10.5/15.8 MB 1.5 MB/s eta 0:00:04
#    --------------------------- ------------ 10.7/15.8 MB 1.5 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.3/15.8 MB 1.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.5/15.8 MB 1.5 MB/s eta 0:00:03
#    ------------------------------ --------- 12.1/15.8 MB 1.5 MB/s eta 0:00:03
#    ------------------------------- -------- 12.3/15.8 MB 1.5 MB/s eta 0:00:03
#    ------------------------------- -------- 12.6/15.8 MB 1.5 MB/s eta 0:00:03
#    --------------------------------- ------ 13.1/15.8 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 13.4/15.8 MB 1.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.6/15.8 MB 1.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.2/15.8 MB 1.6 MB/s eta 0:00:02
#    ------------------------------------ --- 14.4/15.8 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 15.2/15.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 1.6 MB/s  0:00:09
# Downloading orjson-3.11.3-cp310-cp310-win_amd64.whl (131 kB)
# Using cached pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.3-cp310-cp310-win_amd64.whl (107 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading sqlalchemy-2.0.43-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 2.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 2.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.9 MB/s  0:00:01
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading yarl-1.20.1-cp310-cp310-win_amd64.whl (86 kB)
# Downloading zstandard-0.23.0-cp310-cp310-win_amd64.whl (495 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.7.0-cp310-cp310-win_amd64.whl (43 kB)
# Downloading greenlet-3.2.4-cp310-cp310-win_amd64.whl (298 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.3.2-cp310-cp310-win_amd64.whl (41 kB)
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached PyYAML-6.0.2-cp310-cp310-win_amd64.whl (161 kB)
# Installing collected packages: zstandard, urllib3, tenacity, PyYAML, python-dotenv, propcache, orjson, numpy, mypy-extensions, multidict, marshmallow, jsonpointer, httpx-sse, greenlet, frozenlist, charset_normalizer, attrs, async-timeout, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, requests, jsonpatch, aiosignal, requests-toolbelt, pydantic-settings, dataclasses-json, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain, langchain-community
#
#    - --------------------------------------  1/34 [urllib3]
#    - --------------------------------------  1/34 [urllib3]
#    - --------------------------------------  1/34 [urllib3]
#    - --------------------------------------  1/34 [urllib3]
#    - --------------------------------------  1/34 [urllib3]
#    -- -------------------------------------  2/34 [tenacity]
#    --- ------------------------------------  3/34 [PyYAML]
#    --- ------------------------------------  3/34 [PyYAML]
#    --- ------------------------------------  3/34 [PyYAML]
#    ---- -----------------------------------  4/34 [python-dotenv]
#    ---- -----------------------------------  4/34 [python-dotenv]
#    ---- -----------------------------------  4/34 [python-dotenv]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    -------- -------------------------------  7/34 [numpy]
#    --------- ------------------------------  8/34 [mypy-extensions]
#    ----------- ---------------------------- 10/34 [marshmallow]
#    ----------- ---------------------------- 10/34 [marshmallow]
#    -------------- ------------------------- 12/34 [httpx-sse]
#    --------------- ------------------------ 13/34 [greenlet]
#    --------------- ------------------------ 13/34 [greenlet]
#    --------------- ------------------------ 13/34 [greenlet]
#    ----------------- ---------------------- 15/34 [charset_normalizer]
#    ----------------- ---------------------- 15/34 [charset_normalizer]
#    ------------------ --------------------- 16/34 [attrs]
#    ------------------ --------------------- 16/34 [attrs]
#    --------------------- ------------------ 18/34 [aiohappyeyeballs]
#    ---------------------- ----------------- 19/34 [yarl]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------ --------------- 21/34 [SQLAlchemy]
#    ------------------------- -------------- 22/34 [requests]
#    ------------------------- -------------- 22/34 [requests]
#    ------------------------- -------------- 22/34 [requests]
#    ----------------------------- ---------- 25/34 [requests-toolbelt]
#    ----------------------------- ---------- 25/34 [requests-toolbelt]
#    ----------------------------- ---------- 25/34 [requests-toolbelt]
#    ----------------------------- ---------- 25/34 [requests-toolbelt]
#    ------------------------------ --------- 26/34 [pydantic-settings]
#    ------------------------------ --------- 26/34 [pydantic-settings]
#    ------------------------------- -------- 27/34 [dataclasses-json]
#    -------------------------------- ------- 28/34 [aiohttp]
#    -------------------------------- ------- 28/34 [aiohttp]
#    -------------------------------- ------- 28/34 [aiohttp]
#    -------------------------------- ------- 28/34 [aiohttp]
#    -------------------------------- ------- 28/34 [aiohttp]
#    -------------------------------- ------- 28/34 [aiohttp]
#    -------------------------------- ------- 28/34 [aiohttp]
#    ---------------------------------- ----- 29/34 [langsmith]
#    ---------------------------------- ----- 29/34 [langsmith]
#    ---------------------------------- ----- 29/34 [langsmith]
#    ---------------------------------- ----- 29/34 [langsmith]
#    ---------------------------------- ----- 29/34 [langsmith]
#    ---------------------------------- ----- 29/34 [langsmith]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ----------------------------------- ---- 30/34 [langchain-core]
#    ------------------------------------ --- 31/34 [langchain-text-splitters]
#    ------------------------------------ --- 31/34 [langchain-text-splitters]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    ------------------------------------- -- 32/34 [langchain]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    -------------------------------------- - 33/34 [langchain-community]
#    ---------------------------------------- 34/34 [langchain-community]
#
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.43 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 async-timeout-4.0.3 attrs-25.3.0 charset_normalizer-3.4.3 dataclasses-json-0.6.7 frozenlist-1.7.0 greenlet-3.2.4 httpx-sse-0.4.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.27 langchain-community-0.3.17 langchain-core-0.3.76 langchain-text-splitters-0.3.11 langsmith-0.3.45 marshmallow-3.26.1 multidict-6.6.4 mypy-extensions-1.1.0 numpy-1.26.4 orjson-3.11.3 propcache-0.3.2 pydantic-settings-2.10.1 python-dotenv-1.1.1 requests-2.32.5 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-inspect-0.9.0 urllib3-2.5.0 yarl-1.20.1 zstandard-0.23.0

# %%
pip install duckduckgo_search==6.3.5
# Out:
# Collecting duckduckgo_search==6.3.5
#   Using cached duckduckgo_search-6.3.5-py3-none-any.whl.metadata (25 kB)
# Collecting click>=8.1.7 (from duckduckgo_search==6.3.5)
#   Using cached click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting primp>=0.6.5 (from duckduckgo_search==6.3.5)
#   Using cached primp-0.15.0-cp38-abi3-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\luan lima\desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages (from click>=8.1.7->duckduckgo_search==6.3.5) (0.4.6)
# Using cached duckduckgo_search-6.3.5-py3-none-any.whl (27 kB)
# Using cached click-8.3.0-py3-none-any.whl (107 kB)
# Using cached primp-0.15.0-cp38-abi3-win_amd64.whl (3.1 MB)
# Installing collected packages: primp, click, duckduckgo_search
#
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    -------------------------- ------------- 2/3 [duckduckgo_search]
#    -------------------------- ------------- 2/3 [duckduckgo_search]
#    ---------------------------------------- 3/3 [duckduckgo_search]
#
# Successfully installed click-8.3.0 duckduckgo_search-6.3.5 primp-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.tools import DuckDuckGoSearchResults 

def search_web(query:str) -> str:
  return DuckDuckGoSearchResults(backend="news").run(query)

tool_search_web = {'type':'function', 'function':{
  'name': 'search_web',
  'description': 'Search the web',
  'parameters': {'type': 'object', 
                 'required': ['query'],
                 'properties': {
                    'query': {'type':'str', 'description':'the topic or subject to search on the web'},
}}}}
## test
search_web(query="nvidia")
# Out:
# "snippet: Nvidia isn't just selling hardware anymore,' one expert says. The company is increasingly moving to be an equity partner to other AI companies., title: Why Nvidia's $100 billion investment in OpenAI signals a major transformation, link: https://www.msn.com/en-us/money/markets/why-nvidia-s-100-billion-investment-in-openai-signals-a-major-transformation/ar-AA1N4Dja, date: 2025-09-23T16:52:00+00:00, source: MarketWatch, snippet: Nvidia's $100 billion bet on OpenAI has sparked one big question: Where exactly will the electricity come from to power it all?, title: The big challenge to OpenAI's $100B deal with Nvidia: Access to power, link: https://www.msn.com/en-us/money/other/the-big-challenge-to-openais-100-billion-deal-with-nvidia-access-to-power/ar-AA1N9yN0, date: 2025-09-24T04:23:00+00:00, source: Insider, snippet: Nvidia announced Monday it plans to invest up to $100 billion in OpenAI as part of a deal to build out massive data centers for training and running AI models. The companies say they signed a letter of intent to deploy 10 gigawatts — enough to power millions of homes — worth of Nvidia systems to power OpenAI's next generation of AI infrastructure., title: Nvidia plans to invest up to $100B in OpenAI, link: https://www.msn.com/en-us/money/other/nvidia-plans-to-invest-up-to-100b-in-openai/ar-AA1N59LD, date: 2025-09-22T17:26:00+00:00, source: TechCrunch, snippet: O NE THING is clear about the announcement on September 22nd that Nvidia may invest up to $100bn in Open AI in order to help the maker of Chat GPT buy 4m-5m of Nvidia's artificial-intelligence ( AI) chips. Silicon Valley is becoming more incestuous than ever., title: Nvidia's $100bn bet on OpenAI raises more questions than it answers, link: https://www.economist.com/business/2025/09/22/nvidias-100bn-bet-on-openai-raises-more-questions-than-it-answers, date: 2025-09-22T23:23:00+00:00, source: The Economist"

# %%
def search_yf(query:str) -> str:
  return DuckDuckGoSearchResults(backend="news").run(f"site:finance.yahoo.com {query}")

tool_search_yf = {'type':'function', 'function':{
  'name': 'search_yf',
  'description': 'Search for specific financial news',
  'parameters': {'type': 'object', 
                 'required': ['query'],
                 'properties': {
                    'query': {'type':'str', 'description':'the financial topic or subject to search'},
}}}}
## test
search_yf(query="nvidia")
# Out:
# "snippet: Nvidia shares lost ground in early trading Tuesday after logging their largest one-day percentage gain since July on news the AI Favorite plans to invest up to $100 billion in OpenAI. Monitor these key chart levels., title: Nvidia Stock Price Levels to Watch After Chip Giant's $100 Billion Deal With OpenAI, link: https://finance.yahoo.com/news/nvidia-stock-price-levels-watch-135131240.html, date: 2025-09-23T14:12:00+00:00, source: Yahoo Finance, snippet: Alibaba announced on Wednesday a partnership with Nvidia, global data center expansion plans and new artificial intelligence products, as it positions AI as a core business priority alongside its traditional e-commerce operation., title: Alibaba shares leap on Nvidia partnership, data center plans, link: https://finance.yahoo.com/news/alibaba-launches-qwen3-max-ai-025529497.html, date: 2025-09-24T09:47:00+00:00, source: Yahoo Finance, snippet: NVIDIA Corporation (NASDAQ:NVDA) is one of the Best Technology Stocks to Invest in for the Long Term. On September 19, Reuters reported that NVIDIA Corporation (NASDAQ:NVDA) has signed a letter of intent to potentially invest $500 million in Wayve,, title: NVIDIA Corporation (NVDA) to Potentially Invest $500 million in Wayve, link: https://uk.finance.yahoo.com/news/nvidia-corporation-nvda-potentially-invest-080608371.html, date: 2025-09-24T08:06:00+00:00, source: Yahoo Finance UK, snippet: The landmark agreement will boost the ChatGPT maker's computing power with multi-gigawatt data centres, powered by millions of Nvidia's high-speed graphics processing units.View on euronews, title: Nvidia invests $100 billion in OpenAI to fuel its computing power, link: https://finance.yahoo.com/news/nvidia-invests-100-billion-openai-062212429.html, date: 2025-09-23T06:34:00+00:00, source: Yahoo Finance"

# %%
prompt = '''You are an assistant with access to tools, you must decide when to use tools to answer user message.''' 
messages = [{"role":"system", "content":prompt}]

while True:
    ## user input
    try:
        q = input('🙂 >')
    except EOFError:
        break
    if q == "quit":
        break
    if q.strip() == "":
        continue
    messages.append( {"role":"user", "content":q} )
    
    ## model
    agent_res = ollama.chat(
        model=llm,
        #format="json", #or schema
        stream=False,
        tools=[tool_search_web, tool_search_yf],
        messages=messages)
  
    ## response
    dic_tools = {'search_web':search_web, 'search_yf':search_yf}

    if "tool_calls" in agent_res["message"].keys():
        for tool in agent_res["message"]["tool_calls"]:
            t_name, t_inputs = tool["function"]["name"], tool["function"]["arguments"]
            if f := dic_tools.get(t_name):
                ### calling tool
                print('🔧 >', f"\x1b[1;31m{t_name} -> Inputs: {t_inputs}\x1b[0m")
                messages.append( {"role":"user", "content":"use tool '"+t_name+"' with inputs: "+str(t_inputs)} )
                ### tool output
                t_output = f(**tool["function"]["arguments"])
                print(t_output)
                ### final res
                p = f'''Summarize this to answer user question, be as concise as possible: {t_output}'''
                res = ollama.generate(model=llm, prompt=q+". "+p)["response"]
            else:
                print('🤬 >', f"\x1b[1;31m{t_name} -> NotFound\x1b[0m")
  
    if agent_res['message']['content'] != '':
        res = agent_res["message"]["content"]
      
    print("👽 >", f"\x1b[1;30m{res}\x1b[0m")
    messages.append( {"role":"assistant", "content":res} )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 27
#      24 ## response
#      25 dic_tools = {'search_web':search_web, 'search_yf':search_yf}
# ---> 27 if "tool_calls" in agent_res["message"].keys():
#      28     for tool in agent_res["message"]["tool_calls"]:
#      29         t_name, t_inputs = tool["function"]["name"], tool["function"]["arguments"]
#
# File c:\Users\Luan Lima\Desktop\github\34_ai_agents\ai-agents\5_exemplo\.venv\lib\site-packages\pydantic\main.py:991, in BaseModel.__getattr__(self, item)
#     988     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     989 else:
#     990     # this is the current error
# --> 991     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'Message' object has no attribute 'keys'
